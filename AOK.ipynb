# %% [markdown]
# # Arsitektur dan Organisasi Komputer
# ## Input or Output Devices

# %%
print("\033[5;47;46m \n Nama kelompok 5 \033[5;36;40m \n")
print("-Ezra Enrique Tampatty   - NIM 025 \033[5;34;40m \n-Girvan Gabriel Ponto    - NIM 039 \033[5;35;40m \n-Jesica Linggar          - NIM 049 \033[5;37;40m \n-Jordi Enal Ambat        - NIM 021 \033[5;31;40m \n-Richard Toar Pongantung - NIM 059 \033[5;33;40m \n-Shanni Alya Meutia      - NIM 055 ")
# Out:
#
#  Nama kelompok 5
#
# -Ezra Enrique Tampatty   - NIM 025
# -Girvan Gabriel Ponto    - NIM 039
# -Jesica Linggar          - NIM 049
# -Jordi Enal Ambat        - NIM 021
# -Richard Toar Pongantung - NIM 059
# -Shanni Alya Meutia      - NIM 055

# %% [markdown]
# ## Input Devices
# ### What is an input device?

# %%
print("\033[5;37;40m* \033[5;36;40mPerangkat input pada komputer berarti perangkat masukan yang memberi perintah langsung berupa informasi digital pada pengguna.")
print('')
print("\033[5;37;40m- \033[5;36;40mContoh perangkat input pada komputer :")
# Out:
# * Perangkat input pada komputer berarti perangkat masukan yang memberi perintah langsung berupa informasi digital pada pengguna.
#
# - Contoh perangkat input pada komputer :

# %% [markdown]
# ### KEYBOARD

# %%
from IPython.display import Image
Image(filename="keyboard.jpg", width=400, height=400)

# %%
print('\033[5;37;40m* \033[5;36;40m merupakan peranti masukan yang terdiri dari kumpulan huruf, angka dan karakter khusus. Keyboard juga memberikan kemudahan bagi user untuk memberikan perintah yang diperlukan apabila menekan kombinasi antara karakter yang ada pada keyboard dengan tombol-tombol tertentu. ')
# Out:
# *  merupakan peranti masukan yang terdiri dari kumpulan huruf, angka dan karakter khusus. Keyboard juga memberikan kemudahan bagi user untuk memberikan perintah yang diperlukan apabila menekan kombinasi antara karakter yang ada pada keyboard dengan tombol-tombol tertentu.

# %% [markdown]
# ### MOUSE

# %%
from IPython.display import Image
Image(filename="mouse.jpg", width=200, height=200)

# %%
print("\033[5;37;40m- \033[5;36;40m Peranti masukan dengan bentuk seperti tikus ini berfungsi untuk memindahkan pointer atau kursor secara cepat")
# Out:
# -  Peranti masukan dengan bentuk seperti tikus ini berfungsi untuk memindahkan pointer atau kursor secara cepat

# %% [markdown]
# ### FLASHDISK

# %%
from IPython.display import Image
Image(filename="DISK.jpg", width=200, height=200)

# %% [markdown]
# ## Output Devices
# ### What is an output devices?

# %%
print("\033[5;37;40m* \033[5;36;40m Output Device yaitu perangkat keras yang berfungsi untuk mengeluarkan data yang telah diproses sehingga menjadi suatu informasi")
print("\033[5;37;40m- \033[5;36;40m Contoh perangkat output devices:")
# Out:
# *  Output Device yaitu perangkat keras yang berfungsi untuk mengeluarkan data yang telah diproses sehingga menjadi suatu informasi
# -  Contoh perangkat output devices

# %% [markdown]
# ### PRINTER

# %%
from IPython.display import Image
Image(filename="printer.jpg", width=300, height=300)

# %%
print("\033[5;37;40m* \033[5;36;40mperalatan dari komputer yang dapat mencetak teks atau gambar ke media kertas atau media lainnya seperti kertas transparansi")
# Out:
# * peralatan dari komputer yang dapat mencetak teks atau gambar ke media kertas atau media lainnya seperti kertas transparansi

# %% [markdown]
# ### PROYEKTOR

# %%
from IPython.display import Image
Image(filename="proyektor.jpg", width=300, height=300)

# %%
print("\033[1;37;40m* \033[5;36;40mSebuah alat optik yang digunakan untuk menampilkan gambar di sebuah layar proyeksi atau permukaan serupa")
# Out:
# * Sebuah alat optik yang digunakan untuk menampilkan gambar di sebuah layar proyeksi atau permukaan serupa
