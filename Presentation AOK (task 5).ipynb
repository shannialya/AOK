# %% [markdown]
# # Exploratory Data Analysis
# Analisis data eksploratif (Exploratory Data Analysis – EDA) merupakan metode eksplorasi data dengan menggunakan teknik aritmatika sederhana dan teknik grafis dalam meringkas data pengamatan.  EDA merupakan suatu pendekatan, pola/sikap/filosofi tentang bagaimana kita dalam menganalisis sekumpulan data.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# Library yang akan digunakan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Pembacaan dataset dalam format
datarespon = pd.read_csv('datarespon.csv')

# %% [markdown]
# ## Menampilkan 8 data awal dan akhir tabel
# Berikut tampilan data responden yang berisikan bobot nilai dari 1-5 (sangat setuju - sangat tidak setuju)

# %%
datarespon.head(8)
# Out:
#    Apakah anda pernah membuat story board?  \
# 0                                        1
# 1                                        3
# 2                                        1
# 3                                        4
# 4                                        4
# 5                                        1
# 6                                        4
# 7                                        3
#
#    Aplikasi Adobe Photoshop bajakan lebih banyak digunakan dibandingkan yang legal dan berbayar  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  3
# 5                                                  4
# 6                                                  4
# 7                                                  5
#
# ...

# %%
datarespon.tail(8)
# Out:
#      Apakah anda pernah membuat story board?  \
# 496                                        4
# 497                                        4
# 498                                        4
# 499                                        2
# 500                                        3
# 501                                        4
# 502                                        1
# 503                                        2
#
#      Aplikasi Adobe Photoshop bajakan lebih banyak digunakan dibandingkan yang legal dan berbayar  \
# 496                                                  4
# 497                                                  3
# 498                                                  5
# 499                                                  4
# 500                                                  3
# 501                                                  4
# 502                                                  3
# 503                                                  4
#
# ...

# %% [markdown]
# # Deskripsi Data
# Menampilkan detail statistik dasar seperti jumlah data, rata-rata, standar deviasi, dan nilai maksimum dan minimum.

# %%
datarespon.describe()
# Out:
#        Apakah anda pernah membuat story board?  \
# count                               504.000000
# mean                                  2.636905
# std                                   1.173391
# min                                   1.000000
# 25%                                   2.000000
# 50%                                   2.000000
# 75%                                   4.000000
# max                                   5.000000
#
#        Aplikasi Adobe Photoshop bajakan lebih banyak digunakan dibandingkan yang legal dan berbayar  \
# count                                         504.000000
# mean                                            3.878968
# std                                             0.787094
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             4.000000
# ...

# %% [markdown]
# # Menghitung Nilai Korelasi
# Menghitung nilai korelasi dengan metode Kendall dan Spearman

# %% [markdown]
# ## Metode Kendall
# Statistik yang digunakan untuk mengukur hubungan ordinal antara dua kuantitas yang diukur. Korelasi Kendall antara dua variabel akan tinggi ketika pengamatan memiliki peringkat yang sama dan rendah ketika pengamatan memiliki peringkat yang berbeda atau sepenuhnya berbeda untuk korelasi antara kedua variabel.

# %%
correlations = datarespon.corr(method ="kendall") 
correlations
# Out:
#                                                     Apakah anda pernah membuat story board?  \
# Apakah anda pernah membuat story board?                                            1.000000
# Aplikasi Adobe Photoshop bajakan lebih banyak d...                                 0.063965
# Aplikasi Canva lebih banyak dipakai mahasiswa d...                                -0.005127
# Diperlukan waktu lama untuk mahir dalam membuat...                                -0.047781
# Tingkat kesulitan dalam menjalankan aplikasi Canva                                -0.119821
# Jenis font lebih berpengaruh daripada warna font                                   0.007957
# Logo yang baik dapat memperkuat identitas dari ...                                 0.063542
# Pekerjaan desainer grafis sangat diperlukan di ...                                 0.049358
# Bidang profesi desain grafis banyak berkecimpun...                                 0.052951
# ...

# %% [markdown]
# Kesimpulan: pada metode Kendall menunjukkan dua pertanyaan yang memiliki skor tertinggi diantara pertanyaan lainnya, yaitu:
# 1. Pekerjaan desainer grafis sangat diperlukan di masa sekarang
# 2. Pekerjaan dari desain grafis mendapat banyak keuntungan dari dalam perdagangan
#
# Kedua pertanyaan ini mendapatkan nilai korelasi sebesar 0.317891 yang mengindikasikan kedua pertanyaan ini memiliki hubungan yang saling terkait. Kesimpulan yang dapat diambil adalah dikarenakan pekerjaan desainer grafis sangat dibutuhkan di masa sekarang (masa era teknologi modern) dimana industri-industri perdagangan sangat membutuhkan jasa desainer grafis, sehingga desainer grafis mendapatkan banyak sekali keuntungan di dalam dunia perdagangan.

# %% [markdown]
# ## Metode Spearman
# Korelasi Spearman tidak mengasumsikan bahwa data berasal dari distribusi tertentu, jadi itu adalah ukuran korelasi non-parametrik. Korelasi Spearman juga dikenal sebagai korelasi peringkat Spearman karena menghitung koefisien korelasi pada nilai peringkat data.

# %%
correlations = datarespon.corr(method ="spearman") 
correlations
# Out:
#                                                     Apakah anda pernah membuat story board?  \
# Apakah anda pernah membuat story board?                                            1.000000
# Aplikasi Adobe Photoshop bajakan lebih banyak d...                                 0.073657
# Aplikasi Canva lebih banyak dipakai mahasiswa d...                                -0.005886
# Diperlukan waktu lama untuk mahir dalam membuat...                                -0.055901
# Tingkat kesulitan dalam menjalankan aplikasi Canva                                -0.141870
# Jenis font lebih berpengaruh daripada warna font                                   0.009459
# Logo yang baik dapat memperkuat identitas dari ...                                 0.071010
# Pekerjaan desainer grafis sangat diperlukan di ...                                 0.055198
# Bidang profesi desain grafis banyak berkecimpun...                                 0.061096
# ...

# %% [markdown]
# ## Map Korelasi

# %%
# correlation map
## higher correlations are brighter
f,ax = plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Menguji Data Survey
# Membuat uji data dengan Test Alpha Cronbach, T-test, dan Principal Component Analysis (PCA) menggunakan bahasa R

# %% [markdown]
# ## Uji Data dengan Alpha Cronbach

# %%
mydata<-read.csv('dataresponn.csv')

# %%
head(mydata)
# Out:
#   Q1 Q2 Q3 Q4 Q5 Q6 Q7 Q8 Q9 Q10 Q11
# 1 1  5  4  5  4  5  5  5  4  5   4
# 2 3  4  5  3  2  5  5  4  4  3   3
# 3 1  4  3  4  3  4  5  5  4  3   2
# 4 4  5  3  2  3  2  5  4  4  4   5
# 5 4  3  4  2  2  4  5  4  4  4   5
# 6 1  4  3  4  4  4  5  3  3  4   4

# %%
library(psych)
library('psych')
# Out:
# Warning message:
# "package 'psych' was built under R version 3.6.3"

# %%
alpha(mydata)
print('Q1 = Apakah anda pernah membuat story board?')
print('Q2 = Aplikasi Adobe Photoshop bajakan lebih banyak digunakan dibandingkan yang legal dan berbayar')
print('Q3 = Aplikasi Canva lebih banyak dipakai mahasiswa dibandingkan dengan Adobe Photoshop')
print('Q4 = Diperlukan waktu lama untuk mahir dalam membuat poster')
print('Q5 = Tingkat kesulitan dalam menjalankan aplikasi CanvA')
print('Q6 = Jenis font lebih berpengaruh daripada warna font')
print('Q7 = Logo yang baik dapat memperkuat identitas dari sebuah brand')
print('Q8 = Pekerjaan desainer grafis sangat diperlukan di masa sekarang')
print('Q9 = Bidang profesi desain grafis banyak berkecimpung dalam kegiatan penerbitan Publishing House')
print('Q10 = Pekerjaan dari desain grafis mendapat banyak keuntungan dari dalam perdagangan')
print('Q11 = Hasil karya harus dapat membawakan pesan yang dapat diinterpretasikan sama oleh semua pihak')
# Out:
# Warning message in alpha(mydata):
# "Some items were negatively correlated with the total scale and probably
# should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option"
# Some items ( Q5 ) were negatively correlated with the total scale and
# probably should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option
# Reliability analysis
# Call: alpha(x = mydata)
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd median_r
#       0.45      0.51    0.53     0.088 1.1 0.036  3.7 0.33    0.085
#
#  lower alpha upper     95% confidence boundaries
# 0.38 0.45 0.53
#
#  Reliability if an item is dropped:
#     raw_alpha std.alpha G6(smc) average_r  S/N alpha se  var.r med.r
# Q1       0.50      0.53    0.55     0.102 1.14    0.033 0.0114 0.108
# Q2       0.43      0.50    0.52     0.090 0.98    0.038 0.0131 0.085
# Q3       0.47      0.52    0.53     0.099 1.09    0.036 0.0099 0.098
# ...

# %% [markdown]
# ## T-Test

# %%
dataresp<-read.csv('dataresponn.csv')

# %%
head(dataresp)
# Out:
#   Q1 Q2 Q3 Q4 Q5 Q6 Q7 Q8 Q9 Q10 Q11
# 1 1  5  4  5  4  5  5  5  4  5   4
# 2 3  4  5  3  2  5  5  4  4  3   3
# 3 1  4  3  4  3  4  5  5  4  3   2
# 4 4  5  3  2  3  2  5  4  4  4   5
# 5 4  3  4  2  2  4  5  4  4  4   5
# 6 1  4  3  4  4  4  5  3  3  4   4

# %%
attach(mydata)

# %%
names(mydata)
# Out:
#  [1] "Q1"  "Q2"  "Q3"  "Q4"  "Q5"  "Q6"  "Q7"  "Q8"  "Q9"  "Q10" "Q11"

# %%
t.test (Q1,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q1 and Q5
# t = 0.58138, df = 503, p-value = 0.5612
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.09913942  0.18247275
# sample estimates:
# mean of the differences
#              0.04166667

# %%
t.test (Q2,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q2 and Q5
# t = 22.875, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.173472 1.393989
# sample estimates:
# mean of the differences
#                 1.28373

# %%
t.test (Q3,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q3 and Q5
# t = 16.253, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.947144 1.207618
# sample estimates:
# mean of the differences
#                1.077381

# %%
t.test (Q4,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q4 and Q5
# t = 21.311, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.005074 1.209211
# sample estimates:
# mean of the differences
#                1.107143

# %%
t.test (Q6,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q6 and Q5
# t = 18.98, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.9765313 1.2020402
# sample estimates:
# mean of the differences
#                1.089286

# %%
t.test (Q7,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q7 and Q5
# t = 35.555, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.786388 1.995358
# sample estimates:
# mean of the differences
#                1.890873

# %%
t.test (Q8,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q8 and Q5
# t = 31.976, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.651787 1.868054
# sample estimates:
# mean of the differences
#                1.759921

# %%
t.test (Q9,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q9 and Q5
# t = 26.085, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.245751 1.448694
# sample estimates:
# mean of the differences
#                1.347222

# %%
t.test (Q10,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q10 and Q5
# t = 23.658, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.177122 1.390338
# sample estimates:
# mean of the differences
#                 1.28373

# %%
t.test (Q11,Q5, mu=0, alt="two.sided", paired=T, conf.level=0.95)
# Out:
# 	Paired t-test
#
# data:  Q11 and Q5
# t = 32.828, df = 503, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.684440 1.898894
# sample estimates:
# mean of the differences
#                1.791667

# %% [markdown]
# ## Principal Component Analysis

# %%
mydata<-read.csv('dataresponn.csv')

# %%
mydata
# Out:
#     Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10 Q11
# 1   1   5   4   5   4   5   5   5   4   5   4
# 2   3   4   5   3   2   5   5   4   4   3   3
# 3   1   4   3   4   3   4   5   5   4   3   2
# 4   4   5   3   2   3   2   5   4   4   4   5
# 5   4   3   4   2   2   4   5   4   4   4   5
# 6   1   4   3   4   4   4   5   3   3   4   4
# 7   4   4   5   2   1   4   5   5   5   5   5
# 8   3   5   2   3   2   5   5   4   2   4   4
# 9   1   3   3   3   3   3   3   3   3   3   3
# 10  2   4   5   4   2   4   4   4   3   5   4
# 11  1   4   4   2   1   2   4   5   2   4   4
# 12  4   5   5   5   2   4   4   5   5   4   5
# 13  2   4   4   4   2   2   5   5   4   4   4
# 14  1   4   4   4   3   2   4   4   4   4   5
# 15  2   5   4   3   2   4   5   4   4   3   4
# 16  3   5   4   4   2   4   4   5   4   4   5
# 17  2   2   3   4   1   2   5   5   4   5   5
# 18  2   5   5   4   3   3   4   4   4   3   4
# 19  4   4   4   5   2   2   5   5   3   4   5
# ...

# %%
attach(mydata)
# Out:
# The following objects are masked from mydata (pos = 3):
#
#     Q1, Q10, Q11, Q2, Q3, Q4, Q5, Q6, Q7, Q8, Q9

# %%
mydata<-read.csv('dataresponn.csv')

# %%
x <- cbind(Q1, Q2, Q3, Q4, Q5, Q6, Q7, Q8, Q9,Q10,Q11)

# %%
summary(x)
cor(x)
# Out:
#        Q1              Q2              Q3              Q4
#  Min.   :1.000   Min.   :1.000   Min.   :1.000   Min.   :1.000
#  1st Qu.:2.000   1st Qu.:4.000   1st Qu.:3.000   1st Qu.:3.000
#  Median :2.000   Median :4.000   Median :4.000   Median :4.000
#  Mean   :2.637   Mean   :3.879   Mean   :3.673   Mean   :3.702
#  3rd Qu.:4.000   3rd Qu.:4.000   3rd Qu.:4.000   3rd Qu.:4.000
#  Max.   :5.000   Max.   :5.000   Max.   :5.000   Max.   :5.000
#        Q5              Q6              Q7              Q8
#  Min.   :1.000   Min.   :1.000   Min.   :1.000   Min.   :2.000
#  1st Qu.:2.000   1st Qu.:3.000   1st Qu.:4.000   1st Qu.:4.000
#  Median :2.000   Median :4.000   Median :5.000   Median :4.000
#  Mean   :2.595   Mean   :3.685   Mean   :4.486   Mean   :4.355
#  3rd Qu.:3.000   3rd Qu.:4.000   3rd Qu.:5.000   3rd Qu.:5.000
#  Max.   :5.000   Max.   :5.000   Max.   :5.000   Max.   :5.000
#        Q9             Q10             Q11
#  Min.   :1.000   Min.   :2.000   Min.   :1.000
# ...

# %%
pca<-princomp(x, score=TRUE, cor=TRUE)

# %%
# loading of principal component
loadings(pca)
# Out:
# Loadings:
#     Comp.1 Comp.2 Comp.3 Comp.4 Comp.5 Comp.6 Comp.7 Comp.8 Comp.9 Comp.10
# Q1   0.109  0.251  0.300  0.667         0.432  0.347  0.207  0.139
# Q2   0.216        -0.447  0.522 -0.358        -0.302 -0.485         0.126
# Q3   0.211  0.358 -0.594 -0.155  0.175                0.394         0.340
# Q4   0.265 -0.397 -0.296 -0.205 -0.207  0.413  0.232  0.166  0.462 -0.109
# Q5         -0.691  0.147                0.107                       0.356
# Q6   0.229 -0.330 -0.124  0.402  0.229 -0.574         0.428        -0.296
# Q7   0.361  0.100  0.154        -0.472 -0.380  0.482        -0.253  0.356
# Q8   0.466  0.111        -0.168        -0.100  0.246 -0.424  0.193 -0.453
# Q9   0.419 -0.129                0.271  0.361               -0.728 -0.187
# Q10  0.406         0.278         0.479        -0.232 -0.230  0.321  0.502
# Q11  0.293  0.153  0.360        -0.452        -0.616  0.336  0.117 -0.141
#     Comp.11
# Q1   0.120
# Q2
# Q3   0.379
# Q4  -0.349
# Q5   0.587
# Q6
# ...

# %% [markdown]
# # Menampilkan Data dengan Bentuk Grafik
# Plot scree selalu menampilkan nilai eigen dalam kurva ke bawah, mengurutkan nilai eigen dari yang terbesar hingga yang terkecil. Menurut tes scree, "siku" grafik di mana nilai eigen tampaknya mendatar ditemukan dan faktor atau komponen di sebelah kiri titik ini harus dipertahankan sebagai signifikan.Pada Hasil Grafik Plot dan Screeplot menunjukan bahwa komponen satu memiliki grafik tertinggi sehingga harus dipertahankan dan menjadi acuan untuk menentukan nilai PCA semua Komponen

# %%
# Scree plot of eigenvalues
plot(pca)
screeplot(pca, type="line", main="scree plot")
# Out:
# Plot with title "pca"
# Plot with title "scree plot"

# %%
# Biplot of score variables
biplot(pca)
# Out:
# plot without title

# %% [markdown]
# Biplot merupakan salah satu dari sekian banyak metode statistika multivariat yang populer digunakan saat ini, karena mampu menyederhanakan informasi dari banyak peubah menjadi grafik dua dimensi dengan interpretasi yang mudah dipahami.
# Dari segi keeratan hubungan antar peubah (korelasi),
#
# Q1 dan Q3 Memiliki cukup Keeratan korelasi,karna merupakan vektor searah.
#
# Q4 dan Q6 Memiliki cukup Keeratan korelasi,karna merupakan vektor searah.
#
# Q7 dan Q8 juga memiliki keeratan Korelasi dengan membentuk Sudut yang kecil (dibawah 45 derajat) dan tidak berhubungan sama sekali dengan Q5.
#
# Keterangan:
# "Q1 = Apakah anda pernah membuat story board?"
# "Q2 = Aplikasi Adobe Photoshop bajakan lebih banyak digunakan dibandingkan yang legal dan berbayar"
# "Q3 = Aplikasi Canva lebih banyak dipakai mahasiswa dibandingkan dengan Adobe Photoshop"
# "Q4 = Diperlukan waktu lama untuk mahir dalam membuat poster"
# "Q5 = Tingkat kesulitan dalam menjalankan aplikasi CanvA"
# "Q6 = Jenis font lebih berpengaruh daripada warna font"
# "Q7 = Logo yang baik dapat memperkuat identitas dari sebuah brand"
# "Q8 = Pekerjaan desainer grafis sangat diperlukan di masa sekarang"
# "Q9 = Bidang profesi desain grafis banyak berkecimpung dalam kegiatan penerbitan Publishing House"
# "Q10 = Pekerjaan dari desain grafis mendapat banyak keuntungan dari dalam perdagangan"
# "Q11 = Hasil karya harus dapat membawakan pesan yang dapat diinterpretasikan sama oleh semua pihak"

# %%
pca$scores[1:10,]
# Out:
#       Comp.1     Comp.2      Comp.3     Comp.4     Comp.5      Comp.6
#  [1,]  2.1191384 -2.22906566 -1.2725598 -0.2612934  0.02156251 -1.08698956
#  [2,] -0.5156983  0.64608737 -1.8435234  0.9981679  0.69489074 -1.22425969
#  [3,] -0.8617172 -1.47402014 -1.5411317 -0.5196853  0.38635740 -1.22312338
#  [4,] -0.2229824  1.14882827  1.4723581  1.2710245 -1.30807231  0.54318899
#  [5,] -0.0504557  1.68591505  1.5427067  0.5568237  0.34787449 -0.70020157
#  [6,] -1.4746652 -1.92094110 -0.1039882 -0.2522808 -0.93757382 -1.18238802
#  [7,]  2.3423511  2.69836724  0.6187243  0.6139924  1.31251434 -0.45686546
#  [8,] -1.1638256 -0.05313799  0.4613958  2.1751715 -1.13330054 -2.41201443
#  [9,] -4.3689199 -0.89274529 -0.6187337 -0.5873848  1.10362426 -0.03827072
# [10,] -0.1648799  0.48691702 -1.2857904 -0.2275923  1.18177758 -0.55856064
#       Comp.7      Comp.8     Comp.9      Comp.10     Comp.11
#  [1,] -0.03599529 -0.8740945  0.67991165  0.87938705  0.06383629
# ...

# %% [markdown]
# Score PCA memiliki korelasi antara satu dengan yang lainnya. Korelasi yang timbul dapat bersifat positif atau negatif. Korelasi score PCA dilihat dari koefisien korelasi masing–masing pertanyaan satu dengan pertanyaan lain disebut dengan Score Correlation . Angka yang bercetak tebal menunjukkan korelasi antar atribut. Jika nilai korelasi suatu atribut dengan atribut lain bernilai 0.5, atribut tersebut dapat dikatakan berkorelasi, sedangkan jika nilai korelasinya lebih dari 0.8, atribut tersebut dapat dikatakan berkorelasi tinggi (Limpawattana, Shewfelt, 2010).
